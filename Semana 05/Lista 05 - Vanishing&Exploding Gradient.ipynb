# %% [markdown]
# <img src="https://github.com/alan-barzilay/NLPortugues/blob/master/imagens/logo_nlportugues.png?raw=true"  style="height:65%" align="right">
#
#
# # Lista 5 - Vanishing & Exploding Gradient
# **Nome:**
#
# **Numero Usp:**
#
#
#
#
#
#
#
#
#
# ______________

# %% [markdown]
# Nessa lista exploraremos alguns problemas que podemos encontrar ao treinarmos uma rede recorrente. Esses problemas não são únicos das redes recorrentes, qualquer rede profunda pode sofrer de vanishing e exploding gradient mas as redes recorrentes são especialmente instaveis devido a utilização da mesma matriz de pesos repetidas vezes.
#
# Começaremos explorando o exploding gradient e alguns de seus sintomas, em seguida utilizaremos gradient cliping para combate-lo.
# Por fim estudaremos uma rede que sofre de vanishing gradient e utilizaremos o [TensorBoard](??) para visualizar os gradientes e pesos da rede para entender melhor sua dinâmica. Exploraremos tambem algumas maneiras de combater o vanishing gradient e como elas alteram a dinâmica da rede através do TensorBoard.
#
#
#
# Para essa aula é necessario instalar o TensorBoard

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
# %load_ext tensorboard

from sklearn.datasets import make_circles
from numpy import where
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.initializers import RandomUniform





from utils import ExtendedTensorBoard

# %% [markdown]
# # Exploding
#
# Para essa parte da lista nós preparamos uma rede, note como a *loss* cresce exponencialmente até virar infinita e logo em seguida NaN. Esse é um sintoma classico de exploding gradient. O gradiente está tão elevado que a cada etapa de backpropagation o passo de atualização dos parametros leva a um aumento na *loss* e isso segue crescendo até que exploda.

# %%
def f1(x):
    return 5+ 10*x

xs = [x for x in range(100)]
ys = [f1(x) for x in range(100)]

# %%
opt = keras.optimizers.SGD()
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer=opt, loss="mean_squared_error")
model.fit(xs,ys,epochs=400)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 960us/step - loss: 8435758687846400.0000
# Epoch 2/400
# 4/4 [==============================] - 0s 535us/step - loss: 5867692528503078169464646139904.0000
# Epoch 3/400
# 4/4 [==============================] - 0s 509us/step - loss: inf
# Epoch 4/400
# 4/4 [==============================] - 0s 658us/step - loss: inf
# Epoch 5/400
# 4/4 [==============================] - 0s 652us/step - loss: inf
# Epoch 6/400
# 4/4 [==============================] - 0s 884us/step - loss: nan
# Epoch 7/400
# 4/4 [==============================] - 0s 605us/step - loss: nan
# Epoch 8/400
# 4/4 [==============================] - 0s 885us/step - loss: nan
# Epoch 9/400
# 4/4 [==============================] - 0s 493us/step - loss: nan
# Epoch 10/400
# 4/4 [==============================] - 0s 578us/step - loss: nan
# Epoch 11/400
# 4/4 [==============================] - 0s 658us/step - loss: nan
# Epoch 12/400
# 4/4 [==============================] - 0s 532us/step - loss: nan
# Epoch 13/400
# 4/4 [==============================] - 0s 649us/step - loss: nan
# Epoch 14/400
# 4/4 [==============================] - 0s 513us/step - loss: nan
# Epoch 15/400
# 4/4 [==============================] - 0s 543us/step - loss: nan
# Epoch 16/400
# 4/4 [==============================] - 0s 557us/step - loss: nan
# Epoch 17/400
# 4/4 [==============================] - 0s 555us/step - loss: nan
# Epoch 18/400
# 4/4 [==============================] - 0s 551us/step - loss: nan
# Epoch 19/400
# 4/4 [==============================] - 0s 499us/step - loss: nan
# Epoch 20/400
# 4/4 [==============================] - 0s 621us/step - loss: nan
# Epoch 21/400
# 4/4 [==============================] - 0s 613us/step - loss: nan
# Epoch 22/400
# 4/4 [==============================] - 0s 558us/step - loss: nan
# Epoch 23/400
# 4/4 [==============================] - 0s 529us/step - loss: nan
# Epoch 24/400
# 4/4 [==============================] - 0s 477us/step - loss: nan
# Epoch 25/400
# 4/4 [==============================] - 0s 543us/step - loss: nan
# Epoch 26/400
# 4/4 [==============================] - 0s 783us/step - loss: nan
# Epoch 27/400
# 4/4 [==============================] - 0s 539us/step - loss: nan
# Epoch 28/400
# 4/4 [==============================] - 0s 551us/step - loss: nan
# Epoch 29/400
# 4/4 [==============================] - 0s 598us/step - loss: nan
# Epoch 30/400
# 4/4 [==============================] - 0s 529us/step - loss: nan
# Epoch 31/400
# 4/4 [==============================] - 0s 599us/step - loss: nan
# Epoch 32/400
# 4/4 [==============================] - 0s 532us/step - loss: nan
# Epoch 33/400
# 4/4 [==============================] - 0s 698us/step - loss: nan
# Epoch 34/400
# 4/4 [==============================] - 0s 480us/step - loss: nan
# Epoch 35/400
# 4/4 [==============================] - 0s 627us/step - loss: nan
# Epoch 36/400
# 4/4 [==============================] - 0s 660us/step - loss: nan
# Epoch 37/400
# 4/4 [==============================] - 0s 506us/step - loss: nan
# Epoch 38/400
# 4/4 [==============================] - 0s 574us/step - loss: nan
# Epoch 39/400
# 4/4 [==============================] - 0s 486us/step - loss: nan
# Epoch 40/400
# 4/4 [==============================] - 0s 624us/step - loss: nan
# Epoch 41/400
# 4/4 [==============================] - 0s 569us/step - loss: nan
# Epoch 42/400
# 4/4 [==============================] - 0s 581us/step - loss: nan
# Epoch 43/400
# 4/4 [==============================] - 0s 654us/step - loss: nan
# Epoch 44/400
# 4/4 [==============================] - 0s 499us/step - loss: nan
# Epoch 45/400
# 4/4 [==============================] - 0s 704us/step - loss: nan
# Epoch 46/400
# 4/4 [==============================] - 0s 558us/step - loss: nan
# Epoch 47/400
# 4/4 [==============================] - 0s 642us/step - loss: nan
# Epoch 48/400
# 4/4 [==============================] - 0s 541us/step - loss: nan
# Epoch 49/400
# 4/4 [==============================] - 0s 482us/step - loss: nan
# Epoch 50/400
# 4/4 [==============================] - 0s 611us/step - loss: nan
# Epoch 51/400
# 4/4 [==============================] - 0s 529us/step - loss: nan
# Epoch 52/400
# 4/4 [==============================] - 0s 557us/step - loss: nan
# Epoch 53/400
# 4/4 [==============================] - 0s 500us/step - loss: nan
# Epoch 54/400
# 4/4 [==============================] - 0s 572us/step - loss: nan
# Epoch 55/400
# 4/4 [==============================] - 0s 869us/step - loss: nan
# Epoch 56/400
# 4/4 [==============================] - 0s 475us/step - loss: nan
# Epoch 57/400
# 4/4 [==============================] - 0s 570us/step - loss: nan
# Epoch 58/400
# 4/4 [==============================] - 0s 492us/step - loss: nan
# Epoch 59/400
# 4/4 [==============================] - 0s 641us/step - loss: nan
# Epoch 60/400
# 4/4 [==============================] - 0s 804us/step - loss: nan
# Epoch 61/400
# 4/4 [==============================] - 0s 500us/step - loss: nan
# Epoch 62/400
# 4/4 [==============================] - 0s 625us/step - loss: nan
# Epoch 63/400
# 4/4 [==============================] - 0s 577us/step - loss: nan
# Epoch 64/400
# 4/4 [==============================] - 0s 489us/step - loss: nan
# Epoch 65/400
# 4/4 [==============================] - 0s 726us/step - loss: nan
# Epoch 66/400
# 4/4 [==============================] - 0s 508us/step - loss: nan
# Epoch 67/400
# 4/4 [==============================] - 0s 563us/step - loss: nan
# Epoch 68/400
# 4/4 [==============================] - 0s 492us/step - loss: nan
# Epoch 69/400
# 4/4 [==============================] - 0s 570us/step - loss: nan
# Epoch 70/400
# 4/4 [==============================] - 0s 668us/step - loss: nan
# Epoch 71/400
# 4/4 [==============================] - 0s 508us/step - loss: nan
# Epoch 72/400
# 4/4 [==============================] - 0s 590us/step - loss: nan
# Epoch 73/400
# 4/4 [==============================] - 0s 664us/step - loss: nan
# Epoch 74/400
# 4/4 [==============================] - 0s 541us/step - loss: nan
# Epoch 75/400
# 4/4 [==============================] - 0s 641us/step - loss: nan
# Epoch 76/400
# 4/4 [==============================] - 0s 703us/step - loss: nan
# Epoch 77/400
# 4/4 [==============================] - 0s 535us/step - loss: nan
# Epoch 78/400
# 4/4 [==============================] - 0s 726us/step - loss: nan
# Epoch 79/400
# 4/4 [==============================] - 0s 576us/step - loss: nan
# Epoch 80/400
# 4/4 [==============================] - 0s 651us/step - loss: nan
# Epoch 81/400
# 4/4 [==============================] - 0s 564us/step - loss: nan
# Epoch 82/400
# 4/4 [==============================] - 0s 607us/step - loss: nan
# Epoch 83/400
# 4/4 [==============================] - 0s 512us/step - loss: nan
# Epoch 84/400
# 4/4 [==============================] - 0s 518us/step - loss: nan
# Epoch 85/400
# 4/4 [==============================] - 0s 543us/step - loss: nan
# Epoch 86/400
# 4/4 [==============================] - 0s 480us/step - loss: nan
# Epoch 87/400
# 4/4 [==============================] - 0s 603us/step - loss: nan
# Epoch 88/400
# 4/4 [==============================] - 0s 581us/step - loss: nan
# Epoch 89/400
# 4/4 [==============================] - 0s 530us/step - loss: nan
# Epoch 90/400
# 4/4 [==============================] - 0s 814us/step - loss: nan
# Epoch 91/400
# 4/4 [==============================] - 0s 569us/step - loss: nan
# Epoch 92/400
# 4/4 [==============================] - 0s 567us/step - loss: nan
# Epoch 93/400
# 4/4 [==============================] - 0s 618us/step - loss: nan
# Epoch 94/400
# 4/4 [==============================] - 0s 471us/step - loss: nan
# Epoch 95/400
# 4/4 [==============================] - 0s 805us/step - loss: nan
# Epoch 96/400
# 4/4 [==============================] - 0s 558us/step - loss: nan
# Epoch 97/400
# 4/4 [==============================] - 0s 519us/step - loss: nan
# Epoch 98/400
# 4/4 [==============================] - 0s 637us/step - loss: nan
# Epoch 99/400
# 4/4 [==============================] - 0s 703us/step - loss: nan
# Epoch 100/400
# 4/4 [==============================] - 0s 668us/step - loss: nan
# Epoch 101/400
# 4/4 [==============================] - 0s 573us/step - loss: nan
# Epoch 102/400
# 4/4 [==============================] - 0s 489us/step - loss: nan
# Epoch 103/400
# 4/4 [==============================] - 0s 637us/step - loss: nan
# Epoch 104/400
# 4/4 [==============================] - 0s 511us/step - loss: nan
# Epoch 105/400
# 4/4 [==============================] - 0s 875us/step - loss: nan
# Epoch 106/400
# 4/4 [==============================] - 0s 615us/step - loss: nan
# Epoch 107/400
# 4/4 [==============================] - 0s 458us/step - loss: nan
# Epoch 108/400
# 4/4 [==============================] - 0s 520us/step - loss: nan
# Epoch 109/400
# 4/4 [==============================] - 0s 660us/step - loss: nan
# Epoch 110/400
# 4/4 [==============================] - 0s 746us/step - loss: nan
# Epoch 111/400
# 4/4 [==============================] - 0s 569us/step - loss: nan
# Epoch 112/400
# 4/4 [==============================] - 0s 543us/step - loss: nan
# Epoch 113/400
# 4/4 [==============================] - 0s 549us/step - loss: nan
# Epoch 114/400
# 4/4 [==============================] - 0s 701us/step - loss: nan
# Epoch 115/400
# 4/4 [==============================] - 0s 782us/step - loss: nan
# Epoch 116/400
# 4/4 [==============================] - 0s 490us/step - loss: nan
# Epoch 117/400
# 4/4 [==============================] - 0s 510us/step - loss: nan
# Epoch 118/400
# 4/4 [==============================] - 0s 722us/step - loss: nan
# Epoch 119/400
# 4/4 [==============================] - 0s 527us/step - loss: nan
# Epoch 120/400
# 4/4 [==============================] - 0s 880us/step - loss: nan
# Epoch 121/400
# 4/4 [==============================] - 0s 518us/step - loss: nan
# Epoch 122/400
# 4/4 [==============================] - 0s 545us/step - loss: nan
# Epoch 123/400
# 4/4 [==============================] - 0s 551us/step - loss: nan
# Epoch 124/400
# 4/4 [==============================] - 0s 604us/step - loss: nan
# Epoch 125/400
# 4/4 [==============================] - 0s 505us/step - loss: nan
# Epoch 126/400
# 4/4 [==============================] - 0s 554us/step - loss: nan
# Epoch 127/400
# 4/4 [==============================] - 0s 542us/step - loss: nan
# Epoch 128/400
# 4/4 [==============================] - 0s 509us/step - loss: nan
# Epoch 129/400
# 4/4 [==============================] - 0s 609us/step - loss: nan
# Epoch 130/400
# 4/4 [==============================] - 0s 798us/step - loss: nan
# Epoch 131/400
# 4/4 [==============================] - 0s 595us/step - loss: nan
# Epoch 132/400
# 4/4 [==============================] - 0s 555us/step - loss: nan
# Epoch 133/400
# 4/4 [==============================] - 0s 887us/step - loss: nan
# Epoch 134/400
# 4/4 [==============================] - 0s 486us/step - loss: nan
# Epoch 135/400
# 4/4 [==============================] - 0s 728us/step - loss: nan
# Epoch 136/400
# 4/4 [==============================] - 0s 697us/step - loss: nan
# Epoch 137/400
# 4/4 [==============================] - 0s 509us/step - loss: nan
# Epoch 138/400
# 4/4 [==============================] - 0s 574us/step - loss: nan
# Epoch 139/400
# 4/4 [==============================] - 0s 498us/step - loss: nan
# Epoch 140/400
# 4/4 [==============================] - 0s 645us/step - loss: nan
# Epoch 141/400
# 4/4 [==============================] - 0s 616us/step - loss: nan
# Epoch 142/400
# 4/4 [==============================] - 0s 590us/step - loss: nan
# Epoch 143/400
# 4/4 [==============================] - 0s 573us/step - loss: nan
# Epoch 144/400
# 4/4 [==============================] - 0s 706us/step - loss: nan
# Epoch 145/400
# 4/4 [==============================] - 0s 698us/step - loss: nan
# Epoch 146/400
# 4/4 [==============================] - 0s 818us/step - loss: nan
# Epoch 147/400
# 4/4 [==============================] - 0s 673us/step - loss: nan
# Epoch 148/400
# 4/4 [==============================] - 0s 799us/step - loss: nan
# Epoch 149/400
# 4/4 [==============================] - 0s 720us/step - loss: nan
# Epoch 150/400
# 4/4 [==============================] - 0s 894us/step - loss: nan
# Epoch 151/400
# 4/4 [==============================] - 0s 620us/step - loss: nan
# Epoch 152/400
# 4/4 [==============================] - 0s 646us/step - loss: nan
# Epoch 153/400
# 4/4 [==============================] - 0s 651us/step - loss: nan
# Epoch 154/400
# 4/4 [==============================] - 0s 528us/step - loss: nan
# Epoch 155/400
# 4/4 [==============================] - 0s 710us/step - loss: nan
# Epoch 156/400
# 4/4 [==============================] - 0s 567us/step - loss: nan
# Epoch 157/400
# 4/4 [==============================] - 0s 539us/step - loss: nan
# Epoch 158/400
# 4/4 [==============================] - 0s 610us/step - loss: nan
# Epoch 159/400
# 4/4 [==============================] - 0s 646us/step - loss: nan
# Epoch 160/400
# 4/4 [==============================] - 0s 573us/step - loss: nan
# Epoch 161/400
# 4/4 [==============================] - 0s 534us/step - loss: nan
# Epoch 162/400
# 4/4 [==============================] - 0s 511us/step - loss: nan
# Epoch 163/400
# 4/4 [==============================] - 0s 525us/step - loss: nan
# Epoch 164/400
# 4/4 [==============================] - 0s 564us/step - loss: nan
# Epoch 165/400
# 4/4 [==============================] - 0s 623us/step - loss: nan
# Epoch 166/400
# 4/4 [==============================] - 0s 604us/step - loss: nan
# Epoch 167/400
# 4/4 [==============================] - 0s 534us/step - loss: nan
# Epoch 168/400
# 4/4 [==============================] - 0s 573us/step - loss: nan
# Epoch 169/400
# 4/4 [==============================] - 0s 583us/step - loss: nan
# Epoch 170/400
# 4/4 [==============================] - 0s 561us/step - loss: nan
# Epoch 171/400
# 4/4 [==============================] - 0s 531us/step - loss: nan
# Epoch 172/400
# 4/4 [==============================] - 0s 632us/step - loss: nan
# Epoch 173/400
# 4/4 [==============================] - 0s 538us/step - loss: nan
# Epoch 174/400
# 4/4 [==============================] - 0s 492us/step - loss: nan
# Epoch 175/400
# 4/4 [==============================] - 0s 929us/step - loss: nan
# Epoch 176/400
# 4/4 [==============================] - 0s 488us/step - loss: nan
# Epoch 177/400
# 4/4 [==============================] - 0s 451us/step - loss: nan
# Epoch 178/400
# 4/4 [==============================] - 0s 708us/step - loss: nan
# Epoch 179/400
# 4/4 [==============================] - 0s 514us/step - loss: nan
# Epoch 180/400
# 4/4 [==============================] - 0s 608us/step - loss: nan
# Epoch 181/400
# 4/4 [==============================] - 0s 743us/step - loss: nan
# Epoch 182/400
# 4/4 [==============================] - 0s 530us/step - loss: nan
# Epoch 183/400
# 4/4 [==============================] - 0s 509us/step - loss: nan
# Epoch 184/400
# 4/4 [==============================] - 0s 577us/step - loss: nan
# Epoch 185/400
# 4/4 [==============================] - 0s 712us/step - loss: nan
# Epoch 186/400
# 4/4 [==============================] - 0s 573us/step - loss: nan
# Epoch 187/400
# 4/4 [==============================] - 0s 447us/step - loss: nan
# Epoch 188/400
# 4/4 [==============================] - 0s 493us/step - loss: nan
# Epoch 189/400
# 4/4 [==============================] - 0s 512us/step - loss: nan
# Epoch 190/400
# 4/4 [==============================] - 0s 525us/step - loss: nan
# Epoch 191/400
# 4/4 [==============================] - 0s 571us/step - loss: nan
# Epoch 192/400
# 4/4 [==============================] - 0s 495us/step - loss: nan
# Epoch 193/400
# 4/4 [==============================] - 0s 509us/step - loss: nan
# Epoch 194/400
# 4/4 [==============================] - 0s 556us/step - loss: nan
# Epoch 195/400
# 4/4 [==============================] - 0s 626us/step - loss: nan
# Epoch 196/400
# 4/4 [==============================] - 0s 567us/step - loss: nan
# Epoch 197/400
# 4/4 [==============================] - 0s 612us/step - loss: nan
# Epoch 198/400
# 4/4 [==============================] - 0s 561us/step - loss: nan
# Epoch 199/400
# 4/4 [==============================] - 0s 465us/step - loss: nan
# Epoch 200/400
# 4/4 [==============================] - 0s 572us/step - loss: nan
# Epoch 201/400
# 4/4 [==============================] - 0s 510us/step - loss: nan
# Epoch 202/400
# 4/4 [==============================] - 0s 628us/step - loss: nan
# Epoch 203/400
# 4/4 [==============================] - 0s 521us/step - loss: nan
# Epoch 204/400
# 4/4 [==============================] - 0s 533us/step - loss: nan
# Epoch 205/400
# 4/4 [==============================] - 0s 456us/step - loss: nan
# Epoch 206/400
# 4/4 [==============================] - 0s 532us/step - loss: nan
# Epoch 207/400
# 4/4 [==============================] - 0s 558us/step - loss: nan
# Epoch 208/400
# 4/4 [==============================] - 0s 511us/step - loss: nan
# Epoch 209/400
# 4/4 [==============================] - 0s 631us/step - loss: nan
# Epoch 210/400
# 4/4 [==============================] - 0s 473us/step - loss: nan
# Epoch 211/400
# 4/4 [==============================] - 0s 510us/step - loss: nan
# Epoch 212/400
# 4/4 [==============================] - 0s 701us/step - loss: nan
# Epoch 213/400
# 4/4 [==============================] - 0s 541us/step - loss: nan
# Epoch 214/400
# 4/4 [==============================] - 0s 457us/step - loss: nan
# Epoch 215/400
# 4/4 [==============================] - 0s 607us/step - loss: nan
# Epoch 216/400
# 4/4 [==============================] - 0s 676us/step - loss: nan
# Epoch 217/400
# 4/4 [==============================] - 0s 585us/step - loss: nan
# Epoch 218/400
# 4/4 [==============================] - 0s 557us/step - loss: nan
# Epoch 219/400
# 4/4 [==============================] - 0s 468us/step - loss: nan
# Epoch 220/400
# 4/4 [==============================] - 0s 425us/step - loss: nan
# Epoch 221/400
# 4/4 [==============================] - 0s 554us/step - loss: nan
# Epoch 222/400
# 4/4 [==============================] - 0s 529us/step - loss: nan
# Epoch 223/400
# 4/4 [==============================] - 0s 578us/step - loss: nan
# Epoch 224/400
# 4/4 [==============================] - 0s 543us/step - loss: nan
# Epoch 225/400
# 4/4 [==============================] - 0s 544us/step - loss: nan
# Epoch 226/400
# 4/4 [==============================] - 0s 449us/step - loss: nan
# Epoch 227/400
# 4/4 [==============================] - 0s 774us/step - loss: nan
# Epoch 228/400
# 4/4 [==============================] - 0s 500us/step - loss: nan
# Epoch 229/400
# 4/4 [==============================] - 0s 800us/step - loss: nan
# Epoch 230/400
# 4/4 [==============================] - 0s 501us/step - loss: nan
# Epoch 231/400
# 4/4 [==============================] - 0s 479us/step - loss: nan
# Epoch 232/400
# 4/4 [==============================] - 0s 629us/step - loss: nan
# Epoch 233/400
# 4/4 [==============================] - 0s 565us/step - loss: nan
# Epoch 234/400
# 4/4 [==============================] - 0s 548us/step - loss: nan
# Epoch 235/400
# 4/4 [==============================] - 0s 657us/step - loss: nan
# Epoch 236/400
# 4/4 [==============================] - 0s 470us/step - loss: nan
# Epoch 237/400
# 4/4 [==============================] - 0s 639us/step - loss: nan
# Epoch 238/400
# 4/4 [==============================] - 0s 547us/step - loss: nan
# Epoch 239/400
# 4/4 [==============================] - 0s 603us/step - loss: nan
# Epoch 240/400
# 4/4 [==============================] - 0s 538us/step - loss: nan
# Epoch 241/400
# 4/4 [==============================] - 0s 783us/step - loss: nan
# Epoch 242/400
# 4/4 [==============================] - 0s 565us/step - loss: nan
# Epoch 243/400
# 4/4 [==============================] - 0s 672us/step - loss: nan
# Epoch 244/400
# 4/4 [==============================] - 0s 600us/step - loss: nan
# Epoch 245/400
# 4/4 [==============================] - 0s 567us/step - loss: nan
# Epoch 246/400
# 4/4 [==============================] - 0s 558us/step - loss: nan
# Epoch 247/400
# 4/4 [==============================] - 0s 488us/step - loss: nan
# Epoch 248/400
# 4/4 [==============================] - 0s 653us/step - loss: nan
# Epoch 249/400
# 4/4 [==============================] - 0s 558us/step - loss: nan
# Epoch 250/400
# 4/4 [==============================] - 0s 558us/step - loss: nan
# Epoch 251/400
# 4/4 [==============================] - 0s 453us/step - loss: nan
# Epoch 252/400
# 4/4 [==============================] - 0s 469us/step - loss: nan
# Epoch 253/400
# 4/4 [==============================] - 0s 502us/step - loss: nan
# Epoch 254/400
# 4/4 [==============================] - 0s 547us/step - loss: nan
# Epoch 255/400
# 4/4 [==============================] - 0s 588us/step - loss: nan
# Epoch 256/400
# 4/4 [==============================] - 0s 458us/step - loss: nan
# Epoch 257/400
# 4/4 [==============================] - 0s 442us/step - loss: nan
# Epoch 258/400
# 4/4 [==============================] - 0s 439us/step - loss: nan
# Epoch 259/400
# 4/4 [==============================] - 0s 546us/step - loss: nan
# Epoch 260/400
# 4/4 [==============================] - 0s 547us/step - loss: nan
# Epoch 261/400
# 4/4 [==============================] - 0s 531us/step - loss: nan
# Epoch 262/400
# 4/4 [==============================] - 0s 466us/step - loss: nan
# Epoch 263/400
# 4/4 [==============================] - 0s 491us/step - loss: nan
# Epoch 264/400
# 4/4 [==============================] - 0s 652us/step - loss: nan
# Epoch 265/400
# 4/4 [==============================] - 0s 824us/step - loss: nan
# Epoch 266/400
# 4/4 [==============================] - 0s 461us/step - loss: nan
# Epoch 267/400
# 4/4 [==============================] - 0s 486us/step - loss: nan
# Epoch 268/400
# 4/4 [==============================] - 0s 488us/step - loss: nan
# Epoch 269/400
# 4/4 [==============================] - 0s 494us/step - loss: nan
# Epoch 270/400
# 4/4 [==============================] - 0s 521us/step - loss: nan
# Epoch 271/400
# 4/4 [==============================] - 0s 480us/step - loss: nan
# Epoch 272/400
# 4/4 [==============================] - 0s 514us/step - loss: nan
# Epoch 273/400
# 4/4 [==============================] - 0s 595us/step - loss: nan
# Epoch 274/400
# 4/4 [==============================] - 0s 529us/step - loss: nan
# Epoch 275/400
# 4/4 [==============================] - 0s 697us/step - loss: nan
# Epoch 276/400
# 4/4 [==============================] - 0s 592us/step - loss: nan
# Epoch 277/400
# 4/4 [==============================] - 0s 452us/step - loss: nan
# Epoch 278/400
# 4/4 [==============================] - 0s 508us/step - loss: nan
# Epoch 279/400
# 4/4 [==============================] - 0s 550us/step - loss: nan
# Epoch 280/400
# 4/4 [==============================] - 0s 505us/step - loss: nan
# Epoch 281/400
# 4/4 [==============================] - 0s 612us/step - loss: nan
# Epoch 282/400
# 4/4 [==============================] - 0s 530us/step - loss: nan
# Epoch 283/400
# 4/4 [==============================] - 0s 487us/step - loss: nan
# Epoch 284/400
# 4/4 [==============================] - 0s 459us/step - loss: nan
# Epoch 285/400
# 4/4 [==============================] - 0s 420us/step - loss: nan
# Epoch 286/400
# 4/4 [==============================] - 0s 594us/step - loss: nan
# Epoch 287/400
# 4/4 [==============================] - 0s 477us/step - loss: nan
# Epoch 288/400
# 4/4 [==============================] - 0s 495us/step - loss: nan
# Epoch 289/400
# 4/4 [==============================] - 0s 481us/step - loss: nan
# Epoch 290/400
# 4/4 [==============================] - 0s 447us/step - loss: nan
# Epoch 291/400
# 4/4 [==============================] - 0s 442us/step - loss: nan
# Epoch 292/400
# 4/4 [==============================] - 0s 889us/step - loss: nan
# Epoch 293/400
# 4/4 [==============================] - 0s 735us/step - loss: nan
# Epoch 294/400
# 4/4 [==============================] - 0s 534us/step - loss: nan
# Epoch 295/400
# 4/4 [==============================] - 0s 478us/step - loss: nan
# Epoch 296/400
# 4/4 [==============================] - 0s 447us/step - loss: nan
# Epoch 297/400
# 4/4 [==============================] - 0s 858us/step - loss: nan
# Epoch 298/400
# 4/4 [==============================] - 0s 427us/step - loss: nan
# Epoch 299/400
# 4/4 [==============================] - 0s 509us/step - loss: nan
# Epoch 300/400
# 4/4 [==============================] - 0s 581us/step - loss: nan
# Epoch 301/400
# 4/4 [==============================] - 0s 491us/step - loss: nan
# Epoch 302/400
# 4/4 [==============================] - 0s 555us/step - loss: nan
# Epoch 303/400
# 4/4 [==============================] - 0s 577us/step - loss: nan
# Epoch 304/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 305/400
# 4/4 [==============================] - 0s 599us/step - loss: nan
# Epoch 306/400
# 4/4 [==============================] - 0s 495us/step - loss: nan
# Epoch 307/400
# 4/4 [==============================] - 0s 615us/step - loss: nan
# Epoch 308/400
# 4/4 [==============================] - 0s 582us/step - loss: nan
# Epoch 309/400
# 4/4 [==============================] - 0s 586us/step - loss: nan
# Epoch 310/400
# 4/4 [==============================] - 0s 598us/step - loss: nan
# Epoch 311/400
# 4/4 [==============================] - 0s 462us/step - loss: nan
# Epoch 312/400
# 4/4 [==============================] - 0s 501us/step - loss: nan
# Epoch 313/400
# 4/4 [==============================] - 0s 537us/step - loss: nan
# Epoch 314/400
# 4/4 [==============================] - 0s 498us/step - loss: nan
# Epoch 315/400
# 4/4 [==============================] - 0s 841us/step - loss: nan
# Epoch 316/400
# 4/4 [==============================] - 0s 464us/step - loss: nan
# Epoch 317/400
# 4/4 [==============================] - 0s 440us/step - loss: nan
# Epoch 318/400
# 4/4 [==============================] - 0s 794us/step - loss: nan
# Epoch 319/400
# 4/4 [==============================] - 0s 714us/step - loss: nan
# Epoch 320/400
# 4/4 [==============================] - 0s 471us/step - loss: nan
# Epoch 321/400
# 4/4 [==============================] - 0s 501us/step - loss: nan
# Epoch 322/400
# 4/4 [==============================] - 0s 535us/step - loss: nan
# Epoch 323/400
# 4/4 [==============================] - 0s 545us/step - loss: nan
# Epoch 324/400
# 4/4 [==============================] - 0s 554us/step - loss: nan
# Epoch 325/400
# 4/4 [==============================] - 0s 531us/step - loss: nan
# Epoch 326/400
# 4/4 [==============================] - 0s 497us/step - loss: nan
# Epoch 327/400
# 4/4 [==============================] - 0s 468us/step - loss: nan
# Epoch 328/400
# 4/4 [==============================] - 0s 471us/step - loss: nan
# Epoch 329/400
# 4/4 [==============================] - 0s 831us/step - loss: nan
# Epoch 330/400
# 4/4 [==============================] - 0s 690us/step - loss: nan
# Epoch 331/400
# 4/4 [==============================] - 0s 643us/step - loss: nan
# Epoch 332/400
# 4/4 [==============================] - 0s 456us/step - loss: nan
# Epoch 333/400
# 4/4 [==============================] - 0s 513us/step - loss: nan
# Epoch 334/400
# 4/4 [==============================] - 0s 692us/step - loss: nan
# Epoch 335/400
# 4/4 [==============================] - 0s 642us/step - loss: nan
# Epoch 336/400
# 4/4 [==============================] - 0s 488us/step - loss: nan
# Epoch 337/400
# 4/4 [==============================] - 0s 452us/step - loss: nan
# Epoch 338/400
# 4/4 [==============================] - 0s 456us/step - loss: nan
# Epoch 339/400
# 4/4 [==============================] - 0s 539us/step - loss: nan
# Epoch 340/400
# 4/4 [==============================] - 0s 638us/step - loss: nan
# Epoch 341/400
# 4/4 [==============================] - 0s 504us/step - loss: nan
# Epoch 342/400
# 4/4 [==============================] - 0s 561us/step - loss: nan
# Epoch 343/400
# 4/4 [==============================] - 0s 493us/step - loss: nan
# Epoch 344/400
# 4/4 [==============================] - 0s 409us/step - loss: nan
# Epoch 345/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 346/400
# 4/4 [==============================] - 0s 597us/step - loss: nan
# Epoch 347/400
# 4/4 [==============================] - 0s 582us/step - loss: nan
# Epoch 348/400
# 4/4 [==============================] - 0s 460us/step - loss: nan
# Epoch 349/400
# 4/4 [==============================] - 0s 441us/step - loss: nan
# Epoch 350/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 351/400
# 4/4 [==============================] - 0s 561us/step - loss: nan
# Epoch 352/400
# 4/4 [==============================] - 0s 548us/step - loss: nan
# Epoch 353/400
# 4/4 [==============================] - 0s 722us/step - loss: nan
# Epoch 354/400
# 4/4 [==============================] - 0s 649us/step - loss: nan
# Epoch 355/400
# 4/4 [==============================] - 0s 646us/step - loss: nan
# Epoch 356/400
# 4/4 [==============================] - 0s 643us/step - loss: nan
# Epoch 357/400
# 4/4 [==============================] - 0s 526us/step - loss: nan
# Epoch 358/400
# 4/4 [==============================] - 0s 458us/step - loss: nan
# Epoch 359/400
# 4/4 [==============================] - 0s 416us/step - loss: nan
# Epoch 360/400
# 4/4 [==============================] - 0s 527us/step - loss: nan
# Epoch 361/400
# 4/4 [==============================] - 0s 495us/step - loss: nan
# Epoch 362/400
# 4/4 [==============================] - 0s 464us/step - loss: nan
# Epoch 363/400
# 4/4 [==============================] - 0s 676us/step - loss: nan
# Epoch 364/400
# 4/4 [==============================] - 0s 470us/step - loss: nan
# Epoch 365/400
# 4/4 [==============================] - 0s 550us/step - loss: nan
# Epoch 366/400
# 4/4 [==============================] - 0s 823us/step - loss: nan
# Epoch 367/400
# 4/4 [==============================] - 0s 516us/step - loss: nan
# Epoch 368/400
# 4/4 [==============================] - 0s 478us/step - loss: nan
# Epoch 369/400
# 4/4 [==============================] - 0s 504us/step - loss: nan
# Epoch 370/400
# 4/4 [==============================] - 0s 458us/step - loss: nan
# Epoch 371/400
# 4/4 [==============================] - 0s 1ms/step - loss: nan
# Epoch 372/400
# 4/4 [==============================] - 0s 494us/step - loss: nan
# Epoch 373/400
# 4/4 [==============================] - 0s 625us/step - loss: nan
# Epoch 374/400
# 4/4 [==============================] - 0s 579us/step - loss: nan
# Epoch 375/400
# 4/4 [==============================] - 0s 459us/step - loss: nan
# Epoch 376/400
# 4/4 [==============================] - 0s 594us/step - loss: nan
# Epoch 377/400
# 4/4 [==============================] - 0s 561us/step - loss: nan
# Epoch 378/400
# 4/4 [==============================] - 0s 544us/step - loss: nan
# Epoch 379/400
# 4/4 [==============================] - 0s 598us/step - loss: nan
# Epoch 380/400
# 4/4 [==============================] - 0s 514us/step - loss: nan
# Epoch 381/400
# 4/4 [==============================] - 0s 529us/step - loss: nan
# Epoch 382/400
# 4/4 [==============================] - 0s 555us/step - loss: nan
# Epoch 383/400
# 4/4 [==============================] - 0s 658us/step - loss: nan
# Epoch 384/400
# 4/4 [==============================] - 0s 797us/step - loss: nan
# Epoch 385/400
# 4/4 [==============================] - 0s 475us/step - loss: nan
# Epoch 386/400
# 4/4 [==============================] - 0s 495us/step - loss: nan
# Epoch 387/400
# 4/4 [==============================] - 0s 785us/step - loss: nan
# Epoch 388/400
# 4/4 [==============================] - 0s 478us/step - loss: nan
# Epoch 389/400
# 4/4 [==============================] - 0s 441us/step - loss: nan
# Epoch 390/400
# 4/4 [==============================] - 0s 562us/step - loss: nan
# Epoch 391/400
# 4/4 [==============================] - 0s 516us/step - loss: nan
# Epoch 392/400
# 4/4 [==============================] - 0s 513us/step - loss: nan
# Epoch 393/400
# 4/4 [==============================] - 0s 541us/step - loss: nan
# Epoch 394/400
# 4/4 [==============================] - 0s 467us/step - loss: nan
# Epoch 395/400
# 4/4 [==============================] - 0s 462us/step - loss: nan
# Epoch 396/400
# 4/4 [==============================] - 0s 552us/step - loss: nan
# Epoch 397/400
# 4/4 [==============================] - 0s 482us/step - loss: nan
# Epoch 398/400
# 4/4 [==============================] - 0s 809us/step - loss: nan
# Epoch 399/400
# 4/4 [==============================] - 0s 684us/step - loss: nan
# Epoch 400/400
# 4/4 [==============================] - 0s 556us/step - loss: nan

# %% [markdown]
# ## Gradient Cliping
# ## <font color='blue'>Questão 1 </font>
#
#
# Utilizando a mesma arquitetura, realize gradient clipping no otimizador para contornar o problema de exploding gradient, compile e treine seu novo modelo.
# Você pode usar tanto o parametro `clipvalue` quanto `clipnorm` desde que sua rede consiga minimizar a loss.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# Seu código aqui

model.fit(xs,ys,epochs=400)

# %% [markdown]
# ________________________
#
#
#
# # Vanishing
#
# Lidar com Vanishing Gradient é muito mais desafiador do que com exploding gradient. Não é trivial determinar se o baixo desempenho de sua rede é causado por vanishing gradient uma vez que seus sintomas são relativamente genericos e ele pode ser apenas mais um dos fatores que prejudicam seu desempenho. Além disso não existe uma solução geral e definitiva como o gradient cliping em casos de explosão do gradiente.
#
# Preparamos algumas redes para poder explorar um caso mais simples de vanishing gradient e também uma possivel solução. Começamos gerando um dataset simples de classificação e treinamos uma rede rasa que obtem uma boa performance.
# Ao aprofundarmos essa rede podemos notar que sua performance cai drasticamente se tornando quase tão eficiente quanto jogar uma moeda para chutar a classe do ponto, ela nem mesmo é capaz de overfittar os dados. Utilizaremos o TensorBoard para explorar os gradientes dessa rede mais profunda e tentar analisar essa queda de performance. Em seguida utilizaremos uma nova forma de inicialização dos pesos da rede para tentar recuperar nossa performance e novamente inspecionar os seus gradientes para tentar ganhar algum insight do que está acontecendo dentro dela.

# %% [markdown]
# ___________
#
# ## TensorBoard e Callbacks
#
# O TensorBoard é uma ferramenta de monitoramento e visualização de redes neurais. Nós o utilizaremos para visualizar os gradientes de nossa rede e poder entender mais afundo o que está causando nosso fraco desempenho. Para mais informações sobre o TensorBoard recomendamos este [guia da documentação oficial](https://www.tensorflow.org/tensorboard/get_started). O TensorBoard pode ser iniciado como parte do notebook usando a "magica"  `%load_ext tensorboard` para carrega-lo e `%tensorboard --logdir logs/` para inicia-lo. Outra maneira de utiliza-lo é independente pelo terminal a partir dos logs salvos na pasta `log_dir` com o comando `tensorboard --logdir="logs/"`.
#
# Para utilizar o TensorBoard nós utilizamos um callback ao treinar nossa rede.
#
# [Callbacks](https://keras.io/api/callbacks/#tensorboard) são objetos do Keras capazes de realizar ações em diferentes etapas do treinamento, como a cada final de epoch ou antes de cada mini-batch. Três exemplos interessates de callbacks são o [EarlyStopping](https://keras.io/api/callbacks/early_stopping/) que te permite encerrar o treinamento de sua rede quando você atinge uma performance minima desejada, o [ModelCheckpoint](https://keras.io/api/callbacks/model_checkpoint/) que lhe permite criar checkpoints do seu modelo para poder reiniciar o treinamento sem perder todo seu progresso em caso de algum problema (como seus gradientes explodindo por exemplo) e o [LearningRateScheduler](https://keras.io/api/callbacks/learning_rate_scheduler/) que lhe permite alterar o learning rate do seu otimizador conforme a epoch de treinamento.
#
# O TensorBoard possui um callback que nos permite monitorar o desempenho e parâmetros de nosso modelo ao longo do treinamento, porém para guardar os gradientes da rede necessitamos expandir e adaptar o [callback padrão do TensorBoard](https://keras.io/api/callbacks/tensorboard/).
#
# Nós ja implementamos para vocês uma extensão desse callback no arquivo `utils.py`.
# Para usar este callback basta importa-lo e declara-lo da seguinte maneira:
#
#
# ```python
# from utils import ExtendedTensorBoard
# log_dir = "logs/"
# tensorboard_callback = ExtendedTensorBoard(x=dados_treino, y=labels_treino,log_dir=log_dir,histogram_freq=1)
# ```
# ________________

# %% [markdown]
# ## Definindo nossos dados
# Primeiro definiremos um toy dataset bem simples que utilizaremos para nossos modelos e uma função auxiliar para facilitar a comparação de nossos modelos.
#
#
# Esses dados e redes foram inspirados e adaptados [deste post](https://machinelearningmastery.com/how-to-fix-vanishing-gradients-using-the-rectified-linear-activation-function/).

# %%
# gera dataset de classificação 
X, y = make_circles(n_samples=1000, noise=0.1, random_state=1)

# escala input para [-1,1]
scaler = MinMaxScaler(feature_range=(-1, 1))
X = scaler.fit_transform(X)

# plota visualização do dataset
for i in range(2):
    samples_ix = where(y == i)
    plt.scatter(X[samples_ix, 0], X[samples_ix, 1], label=str(i))
plt.legend()
plt.show()

# separa em teste e treino
n_train = 500
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]

# %%
def run_model(model,log_to_tb= False ,trainX=trainX,trainy=trainy,testX=testX,testy=testy):
    """
    Função auxiliar que recebe um modelo e realiza seu treinamento e avaliação no dataset.
    """
    model.summary()
    
    # compila modelo
    opt = keras.optimizers.SGD(lr=0.01, momentum=0.9)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    #Cria log do modelo pra visualizarmos no TensorBoard se a flag estiver ligada
    callbacks = None
    if log_to_tb==True:
        log_dir = "logs/" + model.name
        callbacks=[ExtendedTensorBoard(x=trainX, y=trainy,log_dir=log_dir,histogram_freq=1)]
    

    # fit modelo
    history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=500, verbose=0, callbacks=callbacks)

    # avalia modelo
    _, train_acc = model.evaluate(trainX, trainy, verbose=0)
    _, test_acc = model.evaluate(testX, testy, verbose=0)
    print("\n")
    print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))


    # plota acurácia/training history
    plt.ylim(0, 1)
    plt.title("Acurácia "+ model.name)
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='test')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Rede rasa
# Aqui temos uma rede rasa com apenas uma camada oculta e uma de output, note que ela é capaz de atingir uma performance razoavel após 300 epochs.
#
# Nos estamos utilizando um inicializador diferente do padrão para os pesos da camada, ele retirar os pesos iniciais a partir de uma distribuição uniforme no intervalo [0,1].

# %%
#define modelo raso
init = RandomUniform(minval=0, maxval=1)

model = keras.Sequential(name="modelo_raso")
model.add(keras.layers.Dense(5,
                       input_dim=2,
                       activation="tanh",
                       kernel_initializer=init,
                       name="raso_1"))
model.add(keras.layers.Dense(1,
                       activation='sigmoid',
                       kernel_initializer=init,
                       name="raso_output"))


run_model(model)
# Out:
# Model: "modelo_raso"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# raso_1 (Dense)               (None, 5)                 15
# _________________________________________________________________
# raso_output (Dense)          (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Train: 0.832, Test: 0.846

# %% [markdown]
# ## Rede funda
#
# Agora tornaremos nossa rede mais funda com 5 camadas ocultas e uma de output, note como a performance cai drasticamente e se torna próxima a um chute aleatório. Embora o modelo seja mais complexo e poderoso nós não conseguimos treina-lo.

# %%
# define modelo mais fundo
init = RandomUniform(minval=0, maxval=1)

model = Sequential(name="modelo_fundo")
model.add(Dense(5, input_dim=2, activation='tanh', kernel_initializer=init,name="funda_1"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_2"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_3"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_4"))
model.add(Dense(5, activation='tanh', kernel_initializer=init,name="funda_5"))
model.add(Dense(1, activation='sigmoid', kernel_initializer=init,name="funda_output"))


run_model(model,log_to_tb=True)

# %% [markdown]
# ### Utilizando inicialização de Xavier Glorot
#
# Agora utilizaremos uma técnica de combate ao vanishing gradient, utilizaremos outro inicializador para os pesos da rede. O [inicializador de Xavier Glorot](http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf) é o inicializador default de algumas camadas do keras como a camada densa que utilizamos.

# %%
# define modelo mais fundo com inicializador de pesos melhor
model = Sequential(name="modelo_xavier")
model.add(Dense(5, input_dim=2, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_1"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_2"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_3"))
model.add(Dense(5, activation='tanh', kernel_initializer="glorot_uniform",name="xavier_4"))
model.add(Dense(5, activation='tanh',kernel_initializer="glorot_uniform", name="xavier_5"))
model.add(Dense(1, activation='sigmoid', kernel_initializer="glorot_uniform", name="xavier_output"))

run_model(model,log_to_tb=True)

# %% [markdown]
# ## <font color='blue'>Questão 2 </font>
# Inicialize o TensorBoard e cheque os histogramas e as distribuições dos valores dos gradientes das 2 redes, como eles se diferem de uma rede para outra? Preste atenção em particular para a diferença de amplitude dos seus valores. Que conclusão podemos tirar? Insira/cole imagens do TensorBoard para basear seus argumentos, pode ser uma simples captura de tela.
#
# **Obs:** Você pode filtrar elementos ao escrever a tag "kernel_0_grads" como filtro para facilitar sua exploração dos gradientes dos pesos excluindo os termos de bias/viés.
#
# **Obs2:** Lembre-se de apagar a pasta `logs` se você for retreinar alguma das redes, caso contrário ele irá dar um append nos seus 2 treinamentos e seus graficos de loss e acurácia ficarão errados com loops ligando o começo de um treinamento ao final do outro.
#
# **<font color='red'> Sua resposta aqui </font>**
